# %% [markdown]
# ## World Happiness ##
# The World Happiness Report is a landmark survey of the state of global happiness. We will perform Exploratory Data Analysis (EDA) on the 2021 dataset.

# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=2, suppress=True)
pd.options.display.float_format = '${:,.2f}'.format

# %% [markdown]
# Read in data in csv format as a Pandas data frame. A __DataFrame__ is a 2-dimensional labeled data structure with columns of potentially different types.

# %%
df = pd.read_csv('world-happiness-report-2021.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         $7.84
# 1      Denmark     Western Europe         $7.62
# 2  Switzerland     Western Europe         $7.57
# 3      Iceland     Western Europe         $7.55
# 4  Netherlands     Western Europe         $7.46
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           $0.03         $7.90         $7.78
# 1                           $0.04         $7.69         $7.55
# 2                           $0.04         $7.64         $7.50
# 3                           $0.06         $7.67         $7.44
# 4                           $0.03         $7.52         $7.41
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 $10.78           $0.95                   $72.00
# 1                 $10.93           $0.95                   $72.70
# 2                 $11.12           $0.94                   $74.40
# 3                 $10.88           $0.98                   $73.00
# 4                 $10.93           $0.94                   $72.40
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         $0.95      $-0.10                      $0.19
# 1                         $0.95       $0.03                      $0.18
# 2                         $0.92       $0.03                      $0.29
# 3                         $0.95       $0.16                      $0.67
# 4                         $0.91       $0.17                      $0.34
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                     $2.43                             $1.45
# 1                     $2.43                             $1.50
# 2                     $2.43                             $1.57
# 3                     $2.43                             $1.48
# 4                     $2.43                             $1.50
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         $1.11                                  $0.74
# 1                         $1.11                                  $0.76
# 2                         $1.08                                  $0.82
# 3                         $1.17                                  $0.77
# 4                         $1.08                                  $0.75
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       $0.69                     $0.12
# 1                                       $0.69                     $0.21
# 2                                       $0.65                     $0.20
# 3                                       $0.70                     $0.29
# 4                                       $0.65                     $0.30
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    $0.48                $3.25
# 1                                    $0.48                $2.87
# 2                                    $0.41                $2.84
# 3                                    $0.17                $2.97
# 4                                    $0.38                $2.80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
#  9   Freedom to make life choices                149 non-null    float64
#  10  Generosity                                  149 non-null    float64
#  11  Perceptions of corruption                   149 non-null    float64
#  12  Ladder score in Dystopia                    149 non-null    float64
#  13  Explained by: Log GDP per capita            149 non-null    float64
#  14  Explained by: Social support                149 non-null    float64
#  15  Explained by: Healthy life expectancy       149 non-null    float64
#  16  Explained by: Freedom to make life choices  149 non-null    float64
#  17  Explained by: Generosity                    149 non-null    float64
#  18  Explained by: Perceptions of corruption     149 non-null    float64
#  19  Dystopia + residual                         149 non-null    float64
# dtypes: float64(18), object(2)
# memory usage: 23.4+ KB

# %%
df.shape
# Out:
# (149, 20)

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df = df[['Country name', 'Regional indicator', 'Ladder score',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# %%
df.rename(columns={'Healthy life expectancy': 'Life expectancy', 'Ladder score': 'HappinessScore'}, inplace=True)

# %%
df.head()
# Out:
#   Country name Regional indicator  HappinessScore  Logged GDP per capita  \
# 0      Finland     Western Europe           $7.84                 $10.78
# 1      Denmark     Western Europe           $7.62                 $10.93
# 2  Switzerland     Western Europe           $7.57                 $11.12
# 3      Iceland     Western Europe           $7.55                 $10.88
# 4  Netherlands     Western Europe           $7.46                 $10.93
#
#    Social support  Life expectancy  Freedom to make life choices  Generosity  \
# 0           $0.95           $72.00                         $0.95      $-0.10
# 1           $0.95           $72.70                         $0.95       $0.03
# 2           $0.94           $74.40                         $0.92       $0.03
# 3           $0.98           $73.00                         $0.95       $0.16
# 4           $0.94           $72.40                         $0.91       $0.17
#
#    Perceptions of corruption
# 0                      $0.19
# 1                      $0.18
# 2                      $0.29
# 3                      $0.67
# 4                      $0.34

# %%
df.index
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
df.isnull().sum()
# Out:
# Country name                    0
# Regional indicator              0
# HappinessScore                  0
# Logged GDP per capita           0
# Social support                  0
# Life expectancy                 0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# Pandas __Series__ is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.).

# %%
max_value = df['HappinessScore'].max()
max_value
# Out:
# 7.8420000000000005

# %%
df['HappinessScore'].mean()
# Out:
# 5.532838926174494

# %%
max_index = df['Social support'].idxmax()
max_index
# Out:
# 3

# %%
df.loc[max_index]['Country name']
# Out:
# 'Iceland'

# %%
df.describe()
# Out:
#        HappinessScore  Logged GDP per capita  Social support  Life expectancy  \
# count         $149.00                $149.00         $149.00          $149.00
# mean            $5.53                  $9.43           $0.81           $64.99
# std             $1.07                  $1.16           $0.11            $6.76
# min             $2.52                  $6.63           $0.46           $48.48
# 25%             $4.85                  $8.54           $0.75           $59.80
# 50%             $5.53                  $9.57           $0.83           $66.60
# 75%             $6.25                 $10.42           $0.91           $69.60
# max             $7.84                 $11.65           $0.98           $76.95
#
#        Freedom to make life choices  Generosity  Perceptions of corruption
# count                       $149.00     $149.00                    $149.00
# mean                          $0.79      $-0.02                      $0.73
# std                           $0.11       $0.15                      $0.18
# min                           $0.38      $-0.29                      $0.08
# 25%                           $0.72      $-0.13                      $0.67
# 50%                           $0.80      $-0.04                      $0.78
# 75%                           $0.88       $0.08                      $0.84
# max                           $0.97       $0.54                      $0.94

# %%
df.loc[df['Country name'] == 'Japan']
# Out:
#    Country name Regional indicator  HappinessScore  Logged GDP per capita  \
# 55        Japan          East Asia           $5.94                 $10.61
#
#     Social support  Life expectancy  Freedom to make life choices  Generosity  \
# 55           $0.88           $75.10                         $0.80      $-0.26
#
#     Perceptions of corruption
# 55                      $0.64

# %%
df.sort_values(by=['Life expectancy'], ascending=False)
# Out:
#                   Country name  Regional indicator  HappinessScore  \
# 31                   Singapore      Southeast Asia           $6.38
# 76   Hong Kong S.A.R. of China           East Asia           $5.48
# 55                       Japan           East Asia           $5.94
# 26                       Spain      Western Europe           $6.49
# 2                  Switzerland      Western Europe           $7.57
# ..                         ...                 ...             ...
# 129                  Swaziland  Sub-Saharan Africa           $4.31
# 84                 Ivory Coast  Sub-Saharan Africa           $5.31
# 115                    Nigeria  Sub-Saharan Africa           $4.76
# 144                    Lesotho  Sub-Saharan Africa           $3.51
# 127                       Chad  Sub-Saharan Africa           $4.36
#
#      Logged GDP per capita  Social support  Life expectancy  \
# 31                  $11.49           $0.92           $76.95
# 76                  $11.00           $0.84           $76.82
# 55                  $10.61           $0.88           $75.10
# 26                  $10.57           $0.93           $74.70
# 2                   $11.12           $0.94           $74.40
# ..                     ...             ...              ...
# 129                  $9.06           $0.77           $50.83
# 84                   $8.55           $0.64           $50.11
# 115                  $8.53           $0.74           $50.10
# 144                  $7.93           $0.79           $48.70
# 127                  $7.36           $0.62           $48.48
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 31                          $0.93      $-0.02                      $0.08
# 76                          $0.72       $0.07                      $0.40
# 55                          $0.80      $-0.26                      $0.64
# 26                          $0.76      $-0.08                      $0.74
# 2                           $0.92       $0.03                      $0.29
# ..                            ...         ...                        ...
# 129                         $0.65      $-0.18                      $0.71
# 84                          $0.74      $-0.02                      $0.79
# 115                         $0.74       $0.04                      $0.88
# 144                         $0.71      $-0.13                      $0.92
# 127                         $0.58       $0.04                      $0.81
#
# [149 rows x 9 columns]

# %%
df.nlargest(10, 'Life expectancy')
# Out:
#                  Country name     Regional indicator  HappinessScore  \
# 31                  Singapore         Southeast Asia           $6.38
# 76  Hong Kong S.A.R. of China              East Asia           $5.48
# 55                      Japan              East Asia           $5.94
# 26                      Spain         Western Europe           $6.49
# 2                 Switzerland         Western Europe           $7.57
# 20                     France         Western Europe           $6.69
# 10                  Australia  North America and ANZ           $7.18
# 61                South Korea              East Asia           $5.84
# 38                     Cyprus         Western Europe           $6.22
# 73               North Cyprus         Western Europe           $5.54
#
#     Logged GDP per capita  Social support  Life expectancy  \
# 31                 $11.49           $0.92           $76.95
# 76                 $11.00           $0.84           $76.82
# 55                 $10.61           $0.88           $75.10
# 26                 $10.57           $0.93           $74.70
# 2                  $11.12           $0.94           $74.40
# 20                 $10.70           $0.94           $74.00
# 10                 $10.80           $0.94           $73.90
# 61                 $10.65           $0.80           $73.90
# 38                 $10.58           $0.80           $73.90
# 73                 $10.58           $0.82           $73.90
#
#     Freedom to make life choices  Generosity  Perceptions of corruption
# 31                         $0.93      $-0.02                      $0.08
# 76                         $0.72       $0.07                      $0.40
# 55                         $0.80      $-0.26                      $0.64
# 26                         $0.76      $-0.08                      $0.74
# 2                          $0.92       $0.03                      $0.29
# 20                         $0.82      $-0.15                      $0.57
# 10                         $0.91       $0.16                      $0.44
# 61                         $0.67      $-0.08                      $0.73
# 38                         $0.76      $-0.01                      $0.84
# 73                         $0.80       $0.01                      $0.63

# %%
df.loc[(df['HappinessScore'] > 7) & (df['Life expectancy'] > 73)]
# Out:
#    Country name            Regional indicator  HappinessScore  \
# 2   Switzerland                Western Europe           $7.57
# 5        Norway                Western Europe           $7.39
# 8   New Zealand         North America and ANZ           $7.28
# 9       Austria                Western Europe           $7.27
# 10    Australia         North America and ANZ           $7.18
# 11       Israel  Middle East and North Africa           $7.16
# 13       Canada         North America and ANZ           $7.10
#
#     Logged GDP per capita  Social support  Life expectancy  \
# 2                  $11.12           $0.94           $74.40
# 5                  $11.05           $0.95           $73.30
# 8                  $10.64           $0.95           $73.40
# 9                  $10.91           $0.93           $73.30
# 10                 $10.80           $0.94           $73.90
# 11                 $10.57           $0.94           $73.50
# 13                 $10.78           $0.93           $73.80
#
#     Freedom to make life choices  Generosity  Perceptions of corruption
# 2                          $0.92       $0.03                      $0.29
# 5                          $0.96       $0.09                      $0.27
# 8                          $0.93       $0.13                      $0.24
# 9                          $0.91       $0.04                      $0.48
# 10                         $0.91       $0.16                      $0.44
# 11                         $0.80       $0.03                      $0.75
# 13                         $0.92       $0.09                      $0.41
